# %%
Presion = int(input("Escribe la presión"))
print("La presión es igual a: " + str(Presion) + " Pascales")

Volumen = int(input("Escribe el volumen en metros cúbicos"))
print("El volumen es igual a: " + str(Volumen) + " Metros Cúbicos")

Temperatura = int(input("Escribe la temperatura en grados celsius"))
print("La temperatura es igual a: " + str(Temperatura) + " Grados Celsius")
# Out:
# La presión es igual a: 7 Pascales
# El volumen es igual a: 90 Metros Cúbicos
# La temperatura es igual a: 30 Grados Celsius

# %%
masa =(Presion*Volumen)/(0.37*(Temperatura+460))
print("La masa es igual a: " + str(masa))
# Out:
# La masa es igual a: 3.4749034749034746
